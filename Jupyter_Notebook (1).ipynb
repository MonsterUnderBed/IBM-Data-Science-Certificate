# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __FEI GAO__

# %% [markdown]
# _I am interested in data science because it can provides me with the business insights help me make more informed decisions, and give me different perspectives looking at things_

# %% [markdown]
# ### the purpose of my code is to demonstrate that I can use Jupyter Notebook for the sake of proving that I can use it, cheers

# %%
import numpy as np
import pandas as pd

a = 1
b = 1

print (a+b)
# Out:
# 2

# %% [markdown]
# | a | b |
# | ------ | ------ |
# | 1 | 1 |
#
# ***
#
# - a
# - b
# - c
#
# ***
#
#
#
#
# __[Google](http://www.google.com)__
#
#
# ***
#
# <img src="data:image/jpeg;base64,..." alt="Alt text that describes the graphic" title="Title text" />
